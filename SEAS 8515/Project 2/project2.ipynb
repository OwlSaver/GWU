# %%
import requests
from bs4 import BeautifulSoup
import time
import json
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer

# %%
all_items = []
commitcounter = 0
commits = 0
commitsize = 100
# I observed that each item has a unique number in the URL but some numbers re missing. So, I
# can loop through the numbers and if the link works I can find an item.
# Loop through all the numbers
for item_number in range(0,6010):
    url = f"https://collections.frick.org/objects/{item_number}"
    r = requests.get(url)
    # This number has an item
    if r.status_code == 200:
        # In case I get locked out for pulling too many URLs too fast
        #time.sleep(1)
        title = None
        date_created = None
        acs_num = None
        creator_url = None
        creator = None
        creator_nationality = None
        medium = None
        locations = None
        tags = []
        # Use Beutiful Soup to parse the HTML
        soup = BeautifulSoup(r.text, features="html.parser")
        # I analyzed the HTML to find the infomration I wanted. The following is for each case
        # Title
        title_div = soup.find_all("div",{'class':'detailField titleField'})
        if len(title_div) == 1:
            title = title_div[0].text.strip()
        else:
            print("Title not found")
        # Date created
        date_created_div = soup.find("div",{'class':'detailField displayDateField'})
        if date_created_div != None:
            date_created = date_created_div.find('span',{'class':'detailFieldValue'})
            if date_created != None:
                date_created = date_created.text.strip()
        # Accession number
        acs_num_div = soup.find_all("div",{'class':'detailField invnoField'})
        if len(acs_num_div) == 1:
            acs_num = acs_num_div[0]
            acs_num = acs_num.find("span",{'class':'detailFieldValue'})
            acs_num = acs_num.text.strip()
        # Creator - name and nationality
        creator_div = soup.find('div',{'class':'detailField peopleField'})
        if creator_div != None:
            creator_a_link = creator_div.find('a')
            creator_url = creator_a_link['href']
            creator_data_elements = creator_div.find_all('span')
            if len(creator_data_elements) == 3:
                creator = creator_data_elements[1].text.strip()
                creator_nationality = creator_data_elements[2].text.strip()
            elif len(creator_data_elements) == 2:
                creator = creator_data_elements[1].text.strip()
            elif len(creator_data_elements) == 1:
                creator = creator_data_elements[0].text.strip()
        # Medium
        medium_div = soup.find('div',{'class':'detailField mediumField'})
        if medium_div != None:
            medium = medium_div.find('span',{'class':'detailFieldValue'})
            if medium != None:
                medium = medium.text.strip()
        # Locations
        locations_div = soup.find('div',{'class':'detailField locationsField'})
        if locations_div != None:
            locations = locations_div.find('span',{'class':'loctionFieldLabel'})
            if locations != None:
                locations = locations.text.strip()
        # Tags
        tags_div = soup.find('div',{'class':'detailField collectionsField'})
        if tags_div != None:
            tag_span_elements = tags_div.find_all('span')
            for span in tag_span_elements:
                tags.append(span.text.strip())
        # Put everything collected into a dictionary
        list_item = {
            'url':url
            , 'title':title
            , 'date_created':date_created
            , 'acs_num':acs_num
            , 'creator_url':creator_url
            , 'creator':creator
            , 'creator_nationality':creator_nationality
            , 'medium':medium
            , 'locations':locations
            , 'tags':tags
        }
        # Add to the list
        all_items.append(list_item)
        # Write out every commit size, this allows for restart
        if commitcounter == commitsize:
            commits += 1
            print(f"Commit {commits}")
            with open('frick_data.json','w') as frickfile:
                json.dump(all_items,frickfile,indent=2)
            commitcounter = 0
        else:
            commitcounter += 1
# Write it as JSON so I do not have to keep reruning during analysis
with open('frick_data.json','w') as frickfile:
    json.dump(all_items,frickfile,indent=2)
print("Done")
# Out:
# Commit 1
# Title not found
# Commit 2
# Commit 3
# Commit 4
# Commit 5
# Commit 6
# Commit 7
# Commit 8
# Commit 9
# Commit 10
# Commit 11
# Commit 12
# Commit 13
# Commit 14
# Commit 15
# Title not found
# Commit 16
# Commit 17
# Done

# %%
# Change the pandas settings so we can see all the data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)

with open('frick_data.json', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data)
df.info()
# how many items are there by location
dfSummary = df.groupby("locations").agg(
   items=("url", "count"))
print(dfSummary)
# how many items are there by medium
dfSummary = df.groupby("medium").agg(
   items=("url", "count"))
print(dfSummary)
# for each year, how many items did they acquire and how many were paitings or furniture
# Pull the year from the accession number
df['acs_year'] = (df['acs_num'].astype(str).str[:4])
# Encode the tags as columns with a 1 or 0
mlb = MultiLabelBinarizer()
df = df.join(pd.DataFrame(mlb.fit_transform(df.pop('tags')),
                          columns=mlb.classes_,
                          index=df.index))
print(df.shape)
print(df.columns)
dfSummary = df.groupby("acs_year").agg(
   items_acquired=("url", "count")
   , paintings=("Painting", "sum")
   , sculpture=("Sculpture", "sum")
   , furniture=("Furniture", "sum"))
print(dfSummary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1768 entries, 0 to 1767
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  1768 non-null   object
#  1   title                1766 non-null   object
#  2   date_created         1742 non-null   object
#  3   acs_num              1766 non-null   object
#  4   creator_url          1735 non-null   object
#  5   creator              1519 non-null   object
#  6   creator_nationality  998 non-null    object
#  7   medium               1746 non-null   object
#  8   locations            1766 non-null   object
#  9   tags                 1768 non-null   object
# dtypes: object(10)
# memory usage: 138.3+ KB
#              items
# locations
# Not On View   1766
#                                                     items
# medium
# Alabaster                                               1
# Basswood                                                1
# Beech, walnut, and marble                               2
# Bistre ink on china paper applied to green-tone...      1
# Bistre over graphite, with overdrawing in black...      1
# Black chalk (with evidence in places of chalk d...      1
# Black chalk (with evidence of chalk dipped in o...      1
# Black chalk and pastel on dark brown wove paper         1
# Black chalk on cream laid paper                         2
# Black chalk with stumping on cream laid paper           1
# Black chalk, pen, and iron-gall ink, two shades...      1
# Black, red and brown chalk with touches of blue...      1
# Blue Turquin marble and gilt-bronze mounts              1
# Brass                                                   1
# Brass, and one silver letter opener                     1
# Bronze                                                 87
# Bronze (partial gilt), struck                           1
# Bronze with silver inlays                               1
# Bronze, cast                                            1
# Bronze, partial gilding                                 1
# Bronze, partial gilding and silvering                   1
# Bronze, struck                                          2
# Bronze, with extensive traces of gilding                1
# Brown, black, grey and white gouache over penci...      1
# Brush and brown wash on paper                           1
# Böttger red stoneware                                  10
# Böttger stoneware with black glaze                      1
# Carcass of oak and fir, drawers of oak; veneere...      1
# Carved walnut, cast yellow metal mounts and wro...      1
# Case and figures of gilt bronze on white marble...      1
# Case: gilt bronze, cameos, emeralds, diamonds, ...      1
# Case: gilt bronze, silver enamel, and paste jew...      1
# Cast and sheet gilt brass                               1
# Ceramic on frame                                        1
# Charcoal with brown chalks and stumping on paper        1
# Charcoal with stumping on cream colored paper           1
# Copper alloy (gilt), struck                             1
# Copper alloy (parcel gilt), struck                      1
# Copper alloy (silvered), cast                           1
# Copper alloy with traces of gilding, cast               1
# Copper alloy, cast                                    126
# Copper alloy, cast after a struck original              1
# Copper alloy, cast after original strike                1
# Copper alloy, cast copy of a struck medal               1
# Copper alloy, cast from a struck medal                  1
# Copper alloy, cast from a struck original               1
# Copper alloy, cast from an original strike              1
# Copper alloy, cast, partially gilt                      1
# Copper alloy, pierced, cast                             1
# Copper alloy, struck                                   38
# Copper alloy, struck, restitution medal; cracke...      1
# Copper alloy; struck                                    1
# Copper, struck                                          1
# Cotton (warp and weft), wool (weft), and Senna ...      1
# Cotton, wool and senna                                  5
# Drypoint and engraving, printed in black ink on...      1
# Drypoint, etching and engraving in black ink on...      1
# Drypoint, printed in black ink on cream-colored...      1
# Dyed wool and silk yarns on gilt beechwood              3
# Dyed wool and silk yarns on undyed linen canvas         1
# Dyed wool and silk yarns on undyed linen canvas...      1
# Dyed wool and silk yarns on warps of undyed wool       16
# Dyed wool and silk yarns on wool and gilt walnut        7
# Dyed wool and silk yarns on wool on warps on wa...      8
# Dyed wool on wool warp                                  1
# Ebony and bronze on walnut and fruitwood                1
# Ebony and gilt brass                                    1
# Ebony and oak                                           1
# Ebony on oak                                            1
# Ebony veneer, tôle, gilt-bronze mounts, and mar...      2
# Ebony, pewter and ivory on oak                          1
# Ebony, tulipwood veneer, tôle, gilt bronze, and...      1
# Ebony, tulipwood veneer, tôle, gilt bronze, and...      1
# Ebony, turtle shell, and oak                            1
# Ebony, turtle shell, brass, gilt bronze, and en...      1
# Enamel on copper                                       12
# Enamel on copper with gilt-metal frame                  2
# Enamel on copper, parcel-gilt                           1
# Engraving                                               1
# Engraving, printed in black ink on cream-colore...      2
# Engraving, printed in black ink on dark cream-c...      1
# Etching                                                 2
# Etching and drypoint in black ink on European c...      1
# Etching and drypoint in brownish-black ink on d...      1
# Etching and drypoint in brownish-black ink on p...      1
# Etching and drypoint in dark brown ink on cream...      2
# Etching and drypoint in dark brown ink on dark ...      2
# Etching and drypoint in dark brown ink on pale ...      1
# Etching and drypoint in dark brownish-black ink...      1
# Etching and drypoint in grayish-black ink on cr...      1
# Etching and drypoint with sulphur tint in black...      1
# Etching and drypoint, in black ink on European ...      1
# Etching and drypoint, in brownish-black ink on ...      1
# Etching and drypoint, in brownish-black ink wit...      1
# Etching and drypoint, in dark brown ink with to...      1
# Etching and drypoint, printed in black ink on c...      1
# Etching and drypoint, printed in black ink on d...      1
# Etching and drypoint, printed in black ink on p...      1
# Etching and engraving in black ink on dark crea...      1
# Etching and stipple engraving, printed in color...      1
# Etching on paper                                        1
# Etching with drypoint in brownish-black ink on ...      1
# Etching with drypoint in dark brown ink on crea...      1
# Etching, drypoint and engraving in black ink on...      1
# Etching, drypoint and engraving in black ink on...      1
# Etching, printed in black ink on cream-colored ...      1
# Etching, printed in black ink on cream-colored ...      1
# Etching, printed in black ink on cream-colored ...      1
# Etching, printed in black ink on cream-colored ...      1
# Etching, printed in black ink on dark cream-col...      1
# Etching, printed in black ink on light brown im...      1
# Etching, printed in black ink on pale gray-gree...      1
# Etching, printed in black ink on tan simulated ...      3
# Etching, printed in black ink on tan simulated ...      1
# Etching, printed in black on cream-colored anti...      1
# Etching, printed in brownish-black ink on very ...      1
# Etching, printed in dark brown ink on dark crea...      1
# Faience (tin-glazed earthenware)                       75
# Famille noire porcelain                                19
# Famille noire porcelain on carved wooden base w...      1
# Famille noire porcelain on wood base with brass...      2
# Famille verte porcelain                                13
# Fir veneered with turtle shell, brass, ebony, a...      2
# Gilded brass on brass                                   1
# Gilt and patinated bronze, lapis lazuli and marble      2
# Gilt brass                                              6
# Gilt brass and enamel                                   1
# Gilt brass and silver                                   1
# Gilt brass, brass and steel on oak and mahogany         1
# Gilt brass, glass                                       1
# Gilt brass, steel, polychrome enamel and gold o...      2
# Gilt bronze                                            10
# Gilt bronze and ebony on oak                            1
# Gilt bronze and porphyry                                1
# Gilt bronze on gray marble plinth                       2
# Gilt bronze on marble                                   2
# Gilt bronze on wood                                     1
# Gilt bronze, cast                                       1
# Gilt bronze, lapis lazuli, iron, and oak                1
# Gilt bronze, oak, and Sèvres soft-paste porcelain       1
# Gilt bronze, silver, and enamel                         1
# Gilt copper alloy, cast                                 9
# Gilt copper alloy, cast after a struck original         1
# Gilt copper alloy, struck                               8
# Gilt copper, electrotype after a cast original          1
# Gilt-bronze mounts and hard-paste porcelain; on...      1
# Glazed earthenware                                      3
# Gold and enamel                                         5
# Gold, diamond, rubies and enamel                        1
# Gold, enamel and diamonds                               1
# Gold, enamel, gilt brass, brass, and steel              1
# Gold, gilt brass, and steel                             1
# Gold, gilt brass, enamel, and copper                    1
# Gold, rock crystal, and enamel                          1
# Gossamer Japan paper                                    1
# Gouache and crayons? on canvas                          1
# Gouache and pastel on paper                             1
# Graphite and black chalk on cream paper glued d...      1
# Graphite and black chalk on tracing paper laid ...      1
# Graphite on laid paper                                  1
# Graphite on rose colored wove paper                     1
# Graphite on white laid paper                            1
# Hard-paste porcelain                                  107
# Hard-paste porcelain and gilt bronze                    6
# Hard-paste porcelain and gilt metal mounts              1
# Hard-paste porcelain decorated with underglaze ...      4
# Hard-paste porcelain with gilt-bronze mounts            2
# Hard-paste porcelain with gilt-metal mounts             5
# Hard-paste porcelain with polychrome overglaze         17
# Hard-paste porcelain with silver-gilt mount             1
# Hard-paste porcelain with silver-gilt mounts            4
# Hard-paste porcelain with underglaze blue             212
# Hard-paste porcelain with underglaze blue on br...      1
# Hard-paste porcelain with underglaze blue on wo...      1
# Hard-paste porcelain, Dehua ware                        1
# Hard-paste porcelain, leather, velvet                   1
# Iron and marble                                         1
# Iron, cast                                              1
# Ivory                                                   1
# Lead                                                    4
# Lead (polychromed), cast                                1
# Lead alloy, cast                                        1
# Lead and tin, cast                                      1
# Lead tin alloy, cast                                    2
# Lead, cast                                             25
# Lead-Glazed earthenware                                 1
# Lead-tin alloy, cast                                    1
# Leather                                                 1
# Limoges; enamel on copper, parcel-gilt                 15
# Lithograph printed in black ink on cream-colore...      1
# Lithograph, printed in black ink on cream color...      1
# Mahogany                                                3
# Mahogany, kingwood marquetry, amaranth, gilt-br...      1
# Maplewood                                               2
# Marble                                                 15
# Marble, gilt and patinated bronze                       1
# Marquetry, ivory, tulipwood border, mounts of g...      1
# Marquetry, tulipwood, and laquered bronze mount...      1
# Meissen porcelain                                       1
# Meissen red stoneware                                   1
# Mezzotint                                               2
# Mezzotint printed in black ink on cream-colored...      1
# Mezzotint, printed in black ink on cream-colore...      6
# Mezzotint, printed in black ink on dark cream-c...      1
# Mezzotint, printed in black ink on dark cream-c...      2
# Mezzotint, printed in dark brown ink on cream-c...      1
# Mixed woods                                             1
# Oak and walnut veneered with brass, turtle shel...      1
# Oak and walnut veneered with kingwood and tulip...      1
# Oak and walnut veneered with turtle shell, bras...      2
# Oak veneered with holly, ebony, maple, amaranth...      1
# Oak veneered with maple; plaques of soft-paste ...      1
# Oak veneered with various woods including ash, ...      2
# Oak veneered with various woods including maple...      1
# Oak veneered with various woods including tulip...      1
# Oak with veneered ebony, tulipwood, amaranth, a...      2
# Oak, fir, and walnut veneered with brass, turtl...      1
# Oak, fir, mahogany, gilt bronze, and leather            1
# Oak, mahogany, gilt bronze, and marble                  1
# Oak, pine and mahogany                                  2
# Oil and tempera on panel                                1
# Oil on canvas                                         156
# Oil on mahogany panel                                   1
# Oil on marble                                           1
# Oil on masonite, transferred from panel                 1
# Oil on oak panel                                        9
# Oil on panel                                            6
# Oil on paper mounted on canvas                          1
# Oil on paper, laid down on board                        2
# Oil on silk transferred to canvas                       1
# Oil on wood panel                                       1
# Oil over black chalk with white chalk highlight...      1
# Olive wood and brass on oak, walnut, and burl wood      1
# Painted enamel on copper, partly gilded                30
# Painted enamel on copper, partly gilded, and gi...      1
# Painted enamel on copper, partly gilt                   1
# Pastel on cream paper                                   2
# Pastel on dark brown wove paper                         1
# Pastel on paper affixed to canvas                       1
# Pastel on paper, laid down on canvas                    2
# Pastel, over traces of underdrawing in graphite...      1
# Pen and black ink heightened with white gouache...      1
# Pen and black ink, white heightening, yellow, r...      1
# Pen and brown ink on paper                              2
# Pen and brown ink over black chalk on laid paper        1
# Pen and brown ink, over traces of black chalk           1
# Pen with black ink, white gouache, black ink bo...      1
# Pen with brown ink, brown and gray wash applied...      1
# Pen with brown ink, brown and gray wash applied...      1
# Pen with brown ink, gray wash applied by brush ...      1
# Pen with iron-gall, gray wash and black chalk o...      1
# Pen, brown ink and brown wash on paper                  1
# Pen, iron-gall ink, brown wash, gray wash and w...      1
# Pencil and watercolor on cardboard                      1
# Pencil on paper                                         1
# Pewter, cast                                            1
# Pewter, turtle shell, brass, oak, and pine              1
# Plaster                                                 1
# Polished, diamond faceted stoneware                     1
# Porcelain on stand                                      2
# Porcelain with underglaze blue                          1
# Porcelain, blue and white (soft-paste)                  2
# Porcelain, blue and white, transfer-printed             1
# Print                                                   2
# Recto: Red chalk on paper; Verso: Pen and brown...      1
# Rhinoceros horn                                         1
# Satin                                                   1
# Serpentine and silver-gilt mounts                       1
# Silk (warp and weft) and pashmina (pile)                2
# Silver                                                 14
# Silver and gilt brass                                   1
# Silver gilt                                            11
# Silver gilt, cast                                       2
# Silver gilt, struck                                     4
# Silver gilt, struck, with loop for suspension           1
# Silver, cast                                           53
# Silver, cast with a suspension ring                     1
# Silver, cast, with traces of a loop for suspension      1
# Silver, engraved (?)                                    1
# Silver, gilt, cast                                      1
# Silver, repoussé                                        1
# Silver, struck                                        106
# Silver, struck (?)                                      1
# Silver, tortoiseshell and ebony on oak, ebony, ...      1
# Silver, two cast chased shells soldered together        4
# Silver, two cast schells soldered together              1
# Silver, two cast shells soldered together               9
# Silver-gilt mounted Böttger stoneware                   1
# Soft-paste porcelain                                   35
# Soft-paste porcelain and gilt-bronze mounts             1
# Soft-paste porcelain on a glazed pedestal               1
# Soft-paste porcelain with gilt metal                    3
# Soft-paste porcelain, with later addition of gi...      2
# Soft-paste porcelain, with later addition of gi...      5
# Soft-paste porcelain, with later gilt-bronze mount      1
# State III of V. Etching and drypoint                    1
# Tempera and oil on panel                                1
# Tempera on panel                                        9
# Tempera on poplar panel                                 5
# Tempera or mixed technique on panel                     1
# Terracotta                                              8
# Terracotta, brass, gilt brass, silvered brass, ...      1
# Terracotta, cast                                        2
# Terracotta, coated with dark brown paint flaked...      1
# Tin, probably cast                                      1
# Tin-glazed earthenware                                  1
# Tinted plaster                                          1
# Tortoiseshell, brass, pewter, and ebony marquet...      2
# Tulipwood veneer, holly marquetry, plain tulipw...      1
# Tulipwood, amaranth, gilt bronze, marble on oak...      2
# Tulipwood, fruitwood, amaranth, gilt bronze, an...      1
# Tulipwood, fruitwood, amaranth, gilt-bronze mou...      1
# Tulipwood, kingwood marquetry, gilt-bronze moun...      1
# Velvet                                                  1
# Velvet on silk lining                                   1
# Velvet on walnut                                        3
# Velvet with applique embroidery                         1
# Walnut                                                 25
# Walnut and beech                                        1
# Walnut and gilding                                      2
# Walnut and pine                                         3
# Walnut and poplar, and gilding                          1
# Walnut frame                                           23
# Walnut on oak and mahogany?                             1
# Walnut on pine                                          2
# Walnut wood                                             1
# Walnut, ebony and mastic on wood                        1
# Walnut, gilding and leather                             1
# Walnut, gilding, silk and velvet                        1
# Walnut, gilding, silk, velvet                           3
# Walnut, pine and oak                                    1
# Walnut, pine, ebony and other wood, upholstered...      1
# Watercolor                                              2
# Watercolor and gouache on ivory                         1
# Watercolor and gouache on wove paper with graph...      1
# Watercolor and gouache over graphite on wove paper      1
# Watercolor and graphite on laid paper                   1
# Watercolor on vellum                                    1
# Watercolor over graphite                                1
# Wax on glass                                            1
# Wax on slate                                            1
# Weft-faced tapestry technique of dyed wool and ...      1
# Weft-faced tapestry technique with dyed wool an...      3
# Weft-tapestry technique with dyed wool and silk...      1
# White plaster                                           1
# Wood                                                    1
# Wood veneers, gilt-bronze mounts, and Sèvres po...      1
# Wool                                                    1
# Wool on linen backing                                   1
# (1768, 57)
# Index(['url', 'title', 'date_created', 'acs_num', 'creator_url', 'creator',
#        'creator_nationality', 'medium', 'locations', 'acs_year',
#        '18th and 19th Century Furniture', 'Audio Available', 'Ceramics',
#        'Clocks', 'Cocktails with a Curator', 'Enamels', 'Furniture',
#        'Gilt Bronzes', 'Highlights', 'Master Printmakers of Northern Europe',
#        'Medals', 'Painting', 'Paper', 'Renaissance Furniture', 'Sculpture',
#        'Silver', 'Subject: Portraits', 'Subjects: Animals',
#        'Subjects: At Home', 'Subjects: Cityscapes', 'Subjects: Flowers',
#        'Subjects: Genre', 'Subjects: Seascapes', 'Textiles', 'Virtual Tour',
#        'Vitrual Tour Frick Madison: Room 10, East Wall, Center Panel',
#        'Vitrual Tour: Frick Madison, Room 19, East Wall',
#        'Works Acquired  from 2000 to 2009', 'Works Acquired in 2001',
#        'Works Acquired in 2002', 'Works Acquired in 2004',
#        'Works Acquired in 2005', 'Works Acquired in 2006',
#        'Works Acquired in 2007', 'Works Acquired in 2008',
#        'Works Acquired in 2010', 'Works Acquired in 2011',
#        'Works Acquired in 2012', 'Works Acquired in 2013',
#        'Works Acquired in 2014', 'Works Acquired in 2015',
#        'Works Acquired in 2016', 'Works Acquired in 2017',
#        'Works Acquired in 2019', 'Works Acquired in 2020',
#        'Works Acquired in 2021', 'Works Acquired in 2022'],
#       dtype='object')
#           items_acquired  paintings  sculpture  furniture
# acs_year
# 1895                   1          0          1          0
# 1896                   1          1          0          0
# 1897                   1          1          0          0
# 1898                   2          2          0          0
# 1899                   5          5          0          0
# 1901                   3          3          0          0
# 1902                   3          3          0          0
# 1903                   4          4          0          0
# 1904                   4          4          0          0
# 1905                   7          7          0          0
# 1906                   6          6          0          0
# 1907                   3          3          0          0
# 1908                   2          2          0          0
# 1909                   5          5          0          0
# 1910                  13          5          0          8
# 1911                   6          6          0          0
# 1912                   3          3          0          0
# 1913                  10          2          0          0
# 1914                  46         15          1         25
# 1915                 130         22         12         22
# 1916                 188         27         62         24
# 1917                  17          4          0          0
# 1918                  77          4          1         29
# 1919                   5          3          0          0
# 1920                  51          0          1         34
# 1924                   1          1          0          0
# 1926                   2          2          0          0
# 1927                   4          4          0          0
# 1930                   1          1          0          0
# 1934                  23          0          2          0
# 1935                  12          1          3          0
# 1936                   8          1          0          0
# 1937                   2          2          0          0
# 1938                   1          1          0          0
# 1939                   2          1          1          0
# 1940                   1          0          0          0
# 1942                   1          1          0          0
# 1943                   6          5          1          0
# 1945                   2          1          1          0
# 1946                   2          2          0          0
# 1948                   1          1          0          0
# 1949                   1          1          0          0
# 1950                   3          3          0          0
# 1952                   1          1          0          0
# 1954                   1          1          0          0
# 1955                   1          0          0          1
# 1958                   3          0          0          0
# 1959                   2          0          0          0
# 1960                   1          1          0          0
# 1961                   3          1          2          0
# 1963                   2          0          0          0
# 1965                 225          1          0          6
# 1966                   8          3          0          1
# 1967                   4          0          1          0
# 1968                   3          1          0          0
# 1970                   3          0          1          0
# 1972                   1          0          0          0
# 1973                   1          0          0          0
# 1977                   2          1          0          0
# 1978                  17          0          2          0
# 1979                   7          1          5          0
# 1980                   4          0          0          0
# 1981                   2          1          0          0
# 1982                   3          0          0          0
# 1984                  11          5          1          0
# 1987                   2          0          0          0
# 1988                   1          0          0          0
# 1989                   1          0          0          0
# 1990                   3          0          1          0
# 1991                   1          1          0          0
# 1992                   2          1          1          0
# 1993                   3          1          0          0
# 1994                   4          2          1          0
# 1995                   2          0          0          0
# 1996                   6          0          1          0
# 1997                   4          1          1          0
# 1998                   1          0          0          0
# 1999                  39          0          0          0
# 2001                   2          0          0          0
# 2002                   3          1          2          0
# 2004                   1          0          1          0
# 2005                   2          0          0          0
# 2006                   3          0          3          0
# 2007                   1          0          1          0
# 2008                   2          1          0          0
# 2010                  10          0          0          0
# 2011                   2          0          0          0
# 2012                   1          1          0          0
# 2013                   2          0          1          0
# 2014                  53          1          1          0
# 2015                   2          1          0          0
# 2016                 241          0        215          0
# 2017                   2          2          0          0
# 2019                  57          0          0          0
# 2020                   4          1          0          0
# 2021                 241          0          0          0
# 2022                  97          1          0          0
# None                   2          0          0          0
