# %% [markdown]
# <a href="https://colab.research.google.com/github/OwlSaver/GWU/blob/main/PraxisNotebooks/Praxis_Test_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Goals
#
#
# *   Convert a document to a knowledge graph
# *   Merge knowlege graph

# %% [markdown]
# Architecture
#
#
# *   Input of Prompts or Documents
# *   List item

# %% [markdown]
# To Do
#
# * Handle prompts and documents in STM
# * Convert LTM from flat to a hierarchy
# * How do I keep track of the source of an entity? What if it has multiple sources?
# * Process all the nodes with LTMType of BaseType and look to form type groups
# * Process all the nodes under the same LTMType of BaseType and see if any need to be merged.
# * Turn off the merging in JSON and let it all occur in neo4j

# %%
# Install the necessary libraries
# !pip install python-docx
# !pip install neo4j
# !pip install python-dotenv

# Import the libraries
import docx  # Used for working with .docx files.
import os  # Provides a way to interact with the operating system.
import google.generativeai as genai  # Google’s Generative AI library.
from google.colab import userdata  # Manages user data in Google Colab.
import json  # Parses and manipulates JSON data.
from neo4j import GraphDatabase  # Interacts with the Neo4j graph database.
import re  # Supports working with regular expressions.
import textwrap  # Formats text by wrapping it to a specified width.
import dotenv

# Documentation for the libraries
"""
    python-docx: Library for creating, modifying, and reading .docx files.
    os: Standard library for interacting with the operating system, including file operations.
    google.generativeai: Library for interacting with Google’s Generative AI services.
    google.colab: Library for handling user data in Google Colab environment.
    json: Standard library for parsing and manipulating JSON data.
    neo4j: Library for interacting with Neo4j graph database.
    re: Standard library for working with regular expressions.
    textwrap: Standard library for formatting text by wrapping it to a specified width.
"""
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.3.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.12.2)
# Requirement already satisfied: neo4j in /usr/local/lib/python3.11/dist-packages (5.28.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.0.1)
# '\n    python-docx: Library for creating, modifying, and reading .docx files.\n    os: Standard library for interacting with the operating system, including file operations.\n    google.generativeai: Library for interacting with Google’s Generative AI services.\n    google.colab: Library for handling user data in Google Colab environment.\n    json: Standard library for parsing and manipulating JSON data.\n    neo4j: Library for interacting with Neo4j graph database.\n    re: Standard library for working with regular expressions.\n    textwrap: Standard library for formatting text by wrapping it to a specified width.\n'

# %%
# Mount Google Drive to access the file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class GeminiInitializationError(Exception):
    pass

class GeminiQueryError(Exception):
    pass

class GeminiResponseBlockedError(Exception):
    pass

class ParagraphsTooLong(Exception):
    pass

# %%
class Mind:
  INDENT = 4                    # The numer of characters to indent the json submitted to Gemini.
  MAX_VARIABLE_LENGTH = 2 ** 16 # Adjust as needed.  Consider the context window of your chosen model.
  PARAGRAPH_SET = 50            # The maximum number of paragraphs to process in a set.
  ITERATIONS = 3                # The number of times to process the data
  STM_MAX = 10000               # Once STM reaches this size it will be consolidated to LTM

  Q_KG = '''Create a separate knowledge graph for each named entity you find in the content.
            If you find an entity and know its name but not its type, use "Unknown" for the type.
            If you find an entity and know its type but not its name, use "Unknown" for the name.
            If you find a relationship and know the entity names but not the relationship type, use "Unknown" for the type.
            Do not include explanations of what you did. Use the schema to format your response.
            Do not include the schema in your response. Just include the json in your response.
            The knowledge graph must be in the following json schema format.
            {
              "$schema": "https://json-schema.org/draft/2020-12/schema",
              "$id": "https://example.com/product.schema.json",
              "title": "Frames in JSON.",
              "description": "An approach to use JSON for data in a Frame structure. See A Framework for Representing Knowlege, Marvin Minsky, 1974.",
              "type": "array",
              "entities": {
                "type": "object",
                "properties": {
                  "entityName": { "type": "string" },
                  "entityType": { "type": "string" },
                  "properties": {
                    "type": "array",
                    "items": {
                      "type": "object",
                      "properties": {
                        "propertyName": { "type": "string" },
                        "propertyValue": { "type": "string" }
                      },
                      "required": ["propertyName", "propertyValue"]
                    }
                  },
                  "relationships": {
                    "type": "array",
                    "items": {
                      "type": "object",
                      "properties": {
                        "relationshipType": { "type": "string" },
                        "relationshipTarget": {
                          "type": "object",
                          "properties": {
                            "entityName": { "type": "string" },
                            "entityType": { "type": "string" }
                          },
                          "required": ["entityName", "entityType"]
                        }
                      },
                      "required": ["relationshipType", "relationshipTarget"]
                    }
                  }
                },
                "required": ["entityName", "entityType", "properties", "relationships"]
              }
            }'''
  Q_PC = "How many paragraphs are there in this content?"
  Q_MPC = "Review the content and assume that the estimates are correct. Then add them all togeather for a total count of paragraphs."
  Q_WC = "How many words are there in this content?"
  Q_MWC = "Review the content and assume that the estimates are correct. Then add them all togeather for a total count of words."
  Q_TW = "What are the ten most used words in this content and how often does each occur? Ignore function words for this count."
  Q_MTW = "Review the content and assume that the estimates are correct. Then merge them all togeather for a summarized list of words sorted by frequency."


  def __init__(self):
    load_status = dotenv.load_dotenv("/content/drive/MyDrive/Praxis/Neo4j-839ec4f3-Created-2025-03-07.txt")
    if load_status is False:
      raise RuntimeError('Environment variables not loaded.')

    URI = os.getenv("NEO4J_URI")
    AUTH = (os.getenv("NEO4J_USERNAME"), os.getenv("NEO4J_PASSWORD"))

    self.driver = GraphDatabase.driver(URI, auth=AUTH)
    #self.driver = GraphDatabase.driver(uri, auth=(user, password))
    self.ShortTermMemory = []
    self.LongTermMemory = []

  def text_to_stm(self, variable, question, api_key=None, model_name="gemini-1.5-flash", max_output_tokens=None, temperature=None,  additional_context=None):
    """
    Asks Gemini a question about the contents of a Python variable.

    Args:
        variable: The Python variable to analyze.
        question: The question to ask Gemini about the variable.
        api_key: (Optional) Your Gemini API key.  If not provided, it should be
                  available via genai.configure().
        model_name: (Optional) The Gemini model to use (e.g., "gemini-1.5-pro", "gemini-1.0-pro").  Defaults to "gemini-1.5-pro".
        max_output_tokens: (Optional) Maximum number of tokens in the response.
        temperature: (Optional) Controls the randomness of the response (0.0 - 1.0).  Lower values are more deterministic.
        additional_context: (Optional) A string containing additional information relevant to the variable or question.

    Returns:
        The Gemini API's response as a string, or an error message.

    Raises:
        GeminiInitializationError: If there's an issue initializing the Gemini model.
        GeminiQueryError: If there's an error querying the Gemini API.
        GeminiResponseBlockedError: If the Gemini response is blocked due to content policy.
    """

    if api_key:
        genai.configure(api_key=api_key)


    try:
        model = genai.GenerativeModel(model_name)
    except Exception as e:
      raise GeminiInitializationError(f"Error initializing Gemini model: {str(e)}. Ensure your API key is configured and you have access to the specified model.")

    # --- Improved Prompt Construction ---
    prompt_parts = []
    prompt_parts.append("You are a helpful assistant that can analyze Python variables that contain paragraphs of text and answer questions about them.")

    if additional_context:
        prompt_parts.append(f"Additional Context:\n{additional_context}\n")

    prompt_parts.append(f"Analyze the following Python variable and answer the question below:")

    # --- Improved Variable Handling ---

    # Use a safer representation:  json.dumps is generally better for complex objects.
    try:
        variable_str = json.dumps(variable, indent=self.INDENT, default=str)  # Use default=str to handle non-serializable objects
    except TypeError:
        variable_str = repr(variable) # Fallback to repr if json fails

    # Limit variable size to prevent long prompts
    variable_str = textwrap.shorten(variable_str, width=self.MAX_VARIABLE_LENGTH, placeholder="... (truncated)")

    prompt_parts.append(f"Variable (Python):\n`python\n{variable_str}\n`")

    prompt_parts.append(f"Question:\n{question}")

    # ---  Construct the full prompt  ---
    prompt = "\n\n".join(prompt_parts)

    # --- Generation Configuration ---
    generation_config = {}
    if max_output_tokens is not None:
        generation_config["max_output_tokens"] = max_output_tokens
    if temperature is not None:
        generation_config["temperature"] = temperature

    # Add more safety settings, these are very important
    safety_settings = [
      {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
      },
      {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
      },
      {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
      },
      {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
      },
    ]

    # ---  Generate Response  ---
    try:
        response = model.generate_content(prompt, generation_config=generation_config, safety_settings=safety_settings)
        #  Check for response.prompt_feedback to see if the prompt was blocked.
        if response.prompt_feedback:
          raise GeminiResponseBlockedError(f"Prompt was blocked: {response.prompt_feedback}")
        return response.text
    except Exception as e:
        # More specific error handling:  Catch common errors.
        if "Response was blocked" in str(e):  # Check for content filtering.
            raise GeminiResponseBlockedError(f"Error: Gemini response was blocked due to content policy. Error: {e}")
        raise GeminiQueryError(f"Error querying Gemini API: {str(e)}")

  def close(self):
    self.driver.close()

  def clear_database(self):
    with self.driver.session() as session:
        session.run("MATCH (n) DETACH DELETE n")

  def kg_to_neo4j(self, json_data):
    data = json.loads(json_data)  # Parse the JSON string
    with self.driver.session() as session:
        for entity in data:
            entity_name = entity["entityName"]
            entity_type = entity["entityType"]
            properties = entity["properties"]
            relationships = entity["relationships"]

            # Create or match the entity node
            session.run("""
                MERGE (e:Entity {name: $entity_name, type: $entity_type})
                ON CREATE SET e.created = timestamp()
            """, entity_name=entity_name, entity_type=entity_type)

            # Create or match the entity node and entity type node in the same clause
            # and add LTMType property to the entity type node
            session.run("""
                MERGE (e:Entity {name: $entity_name, type: $entity_type})
                ON CREATE SET e.created = timestamp()
                MERGE (et:EntityType {name: $entity_type})
                ON CREATE SET et.created = timestamp(), et.LTMType = 'BaseType'
                WITH e, et
                MERGE (e)-[:TypeOf]->(et)
            """, entity_name=entity_name, entity_type=entity_type)

            # Set the properties
            for prop in properties:
                prop_name = prop["propertyName"]
                prop_value = prop["propertyValue"]
                session.run("""
                    MATCH (e:Entity {name: $entity_name, type: $entity_type})
                    SET e[$prop_name] = $prop_value
                """, entity_name=entity_name, entity_type=entity_type, prop_name=prop_name, prop_value=prop_value)

            # Create the relationships
            for rel in relationships:
                rel_type = rel["relationshipType"]
                target_name = rel["relationshipTarget"]["entityName"]
                target_type = rel["relationshipTarget"]["entityType"]
                # Sanitize the relationship type: Replace invalid characters with underscores
                rel_type = re.sub(r"[^a-zA-Z0-9_]", "_", rel_type)
                # If rel_type is empty after sanitization, use 'RELATED_TO' as default
                if not rel_type:
                    rel_type = "RELATED_TO"
                # Use the sanitized relationship type in the query
                session.run(f"""
                    MATCH (e:Entity {{name: $entity_name, type: $entity_type}}),
                          (t:Entity {{name: $target_name, type: $target_type}})
                    MERGE (e)-[r:`{rel_type}`]->(t)
                    ON CREATE SET r.created = timestamp()
                """, entity_name=entity_name, entity_type=entity_type, target_name=target_name, target_type=target_type)


  def consolidate_stm_to_ltm(self):
    """
    Consolidate the Short Term Memory into the Long Term Memory.
    """
    new_JSON = ""
    for jsonString in self.ShortTermMemory:
      self.kg_to_neo4j(jsonString)
      if new_JSON == "":
        new_JSON = jsonString
      else:
        new_JSON = self.merge_entities_lists(new_JSON, jsonString)
    if new_JSON != "":
      self.LongTermMemory.append(new_JSON)
    self.ShortTermMemory.clear()

  def merge_entities_lists(self, entities1_str, entities2_str):
      if not entities1_str:
          return entities2_str
      if not entities2_str:
          return entities1_str

      entities1 = json.loads(entities1_str)
      entities2 = json.loads(entities2_str)

      merged_entities = {}

      for entity in entities1 + entities2:
          # Check if 'entityName' and 'entityType' keys exist before creating the key
          if "entityName" in entity and "entityType" in entity:
              key = (entity["entityName"], entity["entityType"])
              if key not in merged_entities:
                  merged_entities[key] = {
                      "entityName": entity["entityName"],
                      "entityType": entity["entityType"],
                      "properties": [],
                      "relationships": []
                  }
              merged_entities[key]["properties"].extend(entity["properties"])
              merged_entities[key]["relationships"].extend(entity["relationships"])
          else:
              # Handle cases where 'entity' or 'type' is missing
              print(f"Warning: Entity missing 'entityName' or 'entityType' key: {entity}")
              # You can choose to skip these entities or handle them differently

      return json.dumps(list(merged_entities.values()), indent=2)

  def clean_ltm(self):
      for i in range(len(self.LongTermMemory)):
          # Parse the JSON string into a list of dictionaries
          entities = json.loads(self.LongTermMemory[i])
          clean_entity_set = self.remove_duplicates(entities)
          # Convert the cleaned entities back to a JSON string
          self.LongTermMemory[i] = json.dumps(clean_entity_set, indent=2)

  def remove_duplicates(self, entities):
      for entity in entities:
          # Remove duplicate properties
          properties = entity["properties"]
          unique_properties = []
          seen_properties = set()
          for prop in properties:
              prop_tuple = (prop["propertyName"], prop["propertyValue"])
              if prop_tuple not in seen_properties:
                  seen_properties.add(prop_tuple)
                  unique_properties.append(prop)
          entity["properties"] = unique_properties

          # Remove duplicate relationships
          relationships = entity["relationships"]
          unique_relationships = []
          seen_relationships = set()
          for rel in relationships:
              rel_tuple = (rel["relationshipType"], rel["relationshipTarget"]["entityName"], rel["relationshipTarget"]["entityType"])
              if rel_tuple not in seen_relationships:
                  seen_relationships.add(rel_tuple)
                  unique_relationships.append(rel)
          entity["relationships"] = unique_relationships

      return entities

  def proccessDocument(self, document):
    for paragraphSet in document:
      print(len(paragraphSet))
      self.processInput(paragraphSet, "document")
    # One last time to make sure STM is clean
    self.consolidate_stm_to_ltm()
    # Get rid of duplicate properties and relationships
    print("Starting clean up")
    self.clean_ltm()
    print(f"STM Len: {len(self.ShortTermMemory)}.")
    print(f"LTM Len: {len(self.LongTermMemory)}.")
    for entitySet in self.LongTermMemory:
      print(len(entitySet))
      print(entitySet)

  def processPrompt(self, prompt):
    pass

  def processInput(self, input, inputType="document"):
    stm_size = 0
    read_pass = 0
    if inputType == "document":
        response = self.text_to_stm(variable=input, question=self.Q_KG, api_key=userdata.get('GeminiAPIKey'), model_name="gemini-1.5-flash")
        # Attempt to extract JSON and remove triple quotes
        try:
            # Search for JSON enclosed in triple quotes
            json_str = re.search(r'\`\`\`json\s*([\s\S]*?)\s*\`\`\`', response, re.DOTALL).group(1)
            # group(1) captures the content inside the triple quotes
            json.loads(json_str)  # This line will raise an exception if json_str is not valid JSON
            self.ShortTermMemory.append(json_str)
        except (AttributeError, json.JSONDecodeError):  # Catch both AttributeError and JSONDecodeError
            # Handle cases where the regex doesn't find a match
            print(f"Warning: Could not extract JSON from response: {response}")

        for textString in self.ShortTermMemory:
            stm_size += len(textString)
        if stm_size > self.STM_MAX:
            self.consolidate_stm_to_ltm()
    elif inputType == "prompt":
        self.ShortTermMemory.append("TBD")
    else:
        raise ValueError("Invalid input type. Must be 'document' or 'prompt'.")

# %%
class Document:

    def __init__(self, path, firstParagraphSet=50, remainingParagraphSet=50):
        """
        Initialize the Document object with the given file path.

        Args:
            path (str): The path to a document that will be analyzed. Must be a
                        Word document in docx format.
            firstParagraphSet (int): The number of paragraphs to extract in the first set.
            remainingParagraphSet (int): The number of paragraphs to extract in the subsequent sets.

        Returns:
            None
        """
        self.doc_path = path
        try:
            self.doc = docx.Document(path)
        except Exception as e:
            raise ValueError("Error opening document: " + str(e))
        self.num_paragraphs = len(self.doc.paragraphs)

        self.restart(firstParagraphSet, remainingParagraphSet)

    def __iter__(self):
        """
        Make the Document object an iterator.

        Returns:
            self: The iterator object itself.
        """
        return self

    def __next__(self):
        """
        Retrieve the next set of paragraphs from the document.

        Returns:
            str: The requested number of paragraphs as a single string. If there are fewer
                 paragraphs remaining, all available paragraphs are returned. If none are
                 available, StopIteration is raised.
        """
        if self.current_paragraph >= self.num_paragraphs:
            raise StopIteration
        else:
            end_paragraph = min(self.current_paragraph + self.currentParagraphSet, self.num_paragraphs)
            extracted_text = [self.doc.paragraphs[i].text for i in range(self.current_paragraph, end_paragraph)]
            retval = '\n'.join(extracted_text)
            self.current_paragraph = end_paragraph
            if self.iteration == 0:
                self.currentParagraphSet = self.remainingParagraphSet
            self.iteration += 1
            return retval

    def __str__(self):
        """
        Provide a string representation of the Document object.

        Returns:
            str: A string describing the document, including its path and the number of paragraphs.
        """
        return f"Document Path: {self.doc_path}\nTotal Paragraphs: {self.num_paragraphs}\nFirst Paragraph Set Size: {self.firstParagraphSet}\nRemaining Paragraph Set Size: {self.remainingParagraphSet}"

    def restart(self, firstParagraphSet=50, remainingParagraphSet=50):
        """
        Restart the iteration process with new paragraph set sizes.

        Args:
            firstParagraphSet (int): The number of paragraphs to extract in the first set.
            remainingParagraphSet (int): The number of paragraphs to extract in the subsequent sets.

        Returns:
            None
        """
        self.firstParagraphSet = firstParagraphSet
        self.remainingParagraphSet = remainingParagraphSet
        self.iteration = 0
        self.current_paragraph = 0
        self.currentParagraphSet = self.firstParagraphSet

    def get_word_count(self):
        """
        Calculate the total number of words in the document.

        Returns:
            int: The total word count.
        """
        total_words = sum(len(paragraph.text.split()) for paragraph in self.doc.paragraphs)
        return total_words

    def search_keyword(self, keyword):
        """
        Search for a keyword in the document and return the paragraphs containing it.

        Args:
            keyword (str): The keyword to search for.

        Returns:
            list: A list of paragraphs containing the keyword.
        """
        paragraphs_with_keyword = [paragraph.text for paragraph in self.doc.paragraphs if keyword in paragraph.text]
        return paragraphs_with_keyword

    def replace_keyword(self, old_keyword, new_keyword):
        """
        Replace a keyword in the document with a new keyword.

        Args:
            old_keyword (str): The keyword to be replaced.
            new_keyword (str): The new keyword to replace the old one.

        Returns:
            None
        """
        for paragraph in self.doc.paragraphs:
            if old_keyword in paragraph.text:
                paragraph.text = paragraph.text.replace(old_keyword, new_keyword)

    def get_paragraph(self, index):
        """
        Retrieve a specific paragraph by its index.

        Args:
            index (int): The index of the paragraph to retrieve.

        Returns:
            str: The text of the specified paragraph.
        """
        if index < 0 or index >= self.num_paragraphs:
            raise IndexError("Paragraph index out of range.")
        return self.doc.paragraphs[index].text

    def save(self, path=None):
        """
        Save the document to a file.

        Args:
            path (str): The file path to save the document. If None, saves to the original path.

        Returns:
            None
        """
        save_path = path if path else self.doc_path
        self.doc.save(save_path)

    def get_statistics(self):
        """
        Retrieve statistics about the document.

        Returns:
            dict: A dictionary containing various statistics about the document.
        """
        statistics = {
            "Total Paragraphs": self.num_paragraphs,
            "Total Words": self.get_word_count(),
            "First Paragraph Set Size": self.firstParagraphSet,
            "Remaining Paragraph Set Size": self.remainingParagraphSet,
        }
        return statistics

# %%
file_path = "/content/drive/MyDrive/Praxis/Conewago Township Sewer Authority, PA.docx"
aDocument1 = Document(file_path, 50, 50)
print(aDocument1.get_word_count())
#aList = aDocument1.search_keyword("sewer")
print(aDocument1)
for paragraph in aDocument1:
  print(len(paragraph))
aDocument1.restart(25, 50)
print(aDocument1)
for paragraph in aDocument1:
  print(len(paragraph))
# Out:
# 21964
# Document Path: /content/drive/MyDrive/Praxis/Conewago Township Sewer Authority, PA.docx
# Total Paragraphs: 1259
# First Paragraph Set Size: 50
# Remaining Paragraph Set Size: 50
# 4008
# 8111
# 4424
# 3851
# 7507
# 2822
# 3625
# 361
# 5929
# 6175
# 6842
# 9301
# 8966
# 9026
# 7484
# 7425
# 4333
# 4706
# 7284
# 5138
# 9153
# 6192
# 2122
# 2122
# 1702
# 8
# Document Path: /content/drive/MyDrive/Praxis/Conewago Township Sewer Authority, PA.docx
# Total Paragraphs: 1259
# First Paragraph Set Size: 25
# Remaining Paragraph Set Size: 50
# 1141
# 5914
# 7969
# 2842
# 6821
# 3861
# 4254
# 1570
# 3421
# 5270
# 6566
# 8815
# 9339
# 8827
# 8558
# 8347
# 4661
# 4472
# 6725
# 5624
# 7010
# 7446
# 4237
# 1119
# 3263
# 545

# %%
# Neo4j connection details

file_path = "/content/drive/MyDrive/Praxis/Conewago Township Sewer Authority, PA.docx"
aDocument = Document(file_path, 50, 50)
aMind = Mind()
try:
  aMind.clear_database()
  aMind.proccessDocument(aDocument)
finally:
  aMind.close()
  print("Done")
# Out:
# 4008
# 8111
# 4424
# 3851
# 7507
# 2822
# 3625
# 361
# 5929
# 6175
# 6842
# 9301
# 8966
# 9026
# 7484
# 7425
# 4333
# 4706
# 7284
# 5138
# 9153
# 6192
# 2122
# 2122
# 1702
# 8
# Starting clean up
# STM Len: 0.
# LTM Len: 7.
# 9340
# [
#   {
#     "entityName": "Conewago Township Sewer Authority",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Name",
#         "propertyValue": "Conewago Township Sewer Authority"
#       },
#       {
#         "propertyName": "Abbreviation",
#         "propertyValue": "CTSA"
#       },
#       {
#         "propertyName": "Establishment Date",
#         "propertyValue": "8-22-1989"
#       },
#       {
#         "propertyName": "Rules and Regulations Adoption Date",
#         "propertyValue": "9-28-2021"
#       },
#       {
#         "propertyName": "Location",
#         "propertyValue": "PA"
#       },
#       {
#         "propertyName": "Bylaws",
#         "propertyValue": "\u00a7 20-7"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "GeographicLocation",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Unknown",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Conewago Township Sewer Authority Rules and Regulations"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "AdoptedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Unknown",
#     "entityType": "Meeting",
#     "properties": [
#       {
#         "propertyName": "Type",
#         "propertyValue": "Annual Meeting"
#       },
#       {
#         "propertyName": "Date",
#         "propertyValue": "January 4th, 7:30 PM"
#       },
#       {
#         "propertyName": "Type",
#         "propertyValue": "Regular Meeting"
#       },
#       {
#         "propertyName": "Frequency",
#         "propertyValue": "Fourth Tuesday of each month, 7:30 PM"
#       },
#       {
#         "propertyName": "Type",
#         "propertyValue": "Special Meeting"
#       },
#       {
#         "propertyName": "Notice Period",
#         "propertyValue": "48 hours"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "HeldBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Chairman",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Vice Chairman",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Secretary-Treasurer",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Assistant Treasurer",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Assistant Secretary",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Treasurer",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Secretary",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "MemberOf",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Solicitor",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "AppointedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Bond Counsel",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "AppointedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Accountant",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "AppointedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Auditor",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "AppointedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Investment Advisor",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "AppointedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Engineer",
#     "entityType": "Role",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "AppointedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Pennsylvania",
#     "entityType": "State",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "CTSA",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "description",
#         "propertyValue": "Conewago Township Sewer Authority"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "hasPolicy",
#         "relationshipTarget": {
#           "entityName": "Delinquency Policy",
#           "entityType": "Policy"
#         }
#       },
#       {
#         "relationshipType": "employs",
#         "relationshipTarget": {
#           "entityName": "Unknown",
#           "entityType": "Staff"
#         }
#       },
#       {
#         "relationshipType": "uses",
#         "relationshipTarget": {
#           "entityName": "Third-party billing agent",
#           "entityType": "Organization"
#         }
#       },
#       {
#         "relationshipType": "hasBoard",
#         "relationshipTarget": {
#           "entityName": "CTSA Board",
#           "entityType": "Governing Body"
#         }
#       },
#       {
#         "relationshipType": "hasSolicitor",
#         "relationshipTarget": {
#           "entityName": "CTSA Solicitor",
#           "entityType": "Legal Professional"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Delinquency Policy",
#     "entityType": "Policy",
#     "properties": [
#       {
#         "propertyName": "delinquentThreshold",
#         "propertyValue": "60 or more days late"
#       },
#       {
#         "propertyName": "warningNotice",
#         "propertyValue": "written warning notice"
#       },
#       {
#         "propertyName": "installmentPlanAllowed",
#         "propertyValue": "true"
#       },
#       {
#         "propertyName": "waterShutoffAuthorized",
#         "propertyValue": "true"
#       },
#       {
#         "propertyName": "municipalLiensAllowed",
#         "propertyValue": "true"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "York Water Company",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania Law",
#     "entityType": "Legal Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Developer",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "pays",
#         "relationshipTarget": {
#           "entityName": "Sewer Authority Solicitor",
#           "entityType": "Legal Professional"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Sewer Authority Solicitor",
#     "entityType": "Legal Professional",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "worksFor",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Municipalities Planning Code",
#     "entityType": "Legal Document",
#     "properties": [],
#     "relationships": []
#   }
# ]
# 11737
# [
#   {
#     "entityName": "Conewago Township Sewer Authority",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Resolution 1999-1",
#         "propertyValue": "Adopted Chapter 82 on 1-26-1999"
#       },
#       {
#         "propertyName": "Resolution 2009-1",
#         "propertyValue": "Adopted Chapter 99 on 4-28-2009"
#       },
#       {
#         "propertyName": "Adoption Date (Resolution 2010-1)",
#         "propertyValue": "1-26-2010"
#       },
#       {
#         "propertyName": "Adoption Date (Resolution 2020-1)",
#         "propertyValue": "2-28-2020"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Solicitor",
#     "entityType": "Profession",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Developer",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Sewer Authority",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 46",
#     "entityType": "Legal Document Section",
#     "properties": [
#       {
#         "propertyName": "topic",
#         "propertyValue": "Fees and Escrow Funds"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 60",
#     "entityType": "Legal Document Section",
#     "properties": [
#       {
#         "propertyName": "topic",
#         "propertyValue": "Grinder Pump Charges for Excess Maintenance"
#       },
#       {
#         "propertyName": "adoptedDate",
#         "propertyValue": "2-25-2014"
#       },
#       {
#         "propertyName": "amendedDate",
#         "propertyValue": "7-25-2023"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 71",
#     "entityType": "Legal Document Section",
#     "properties": [
#       {
#         "propertyName": "topic",
#         "propertyValue": "High Strength Waste Testing"
#       },
#       {
#         "propertyName": "adoptedDate",
#         "propertyValue": "6-26-2007"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 2014-1",
#     "entityType": "Resolution",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "adoptedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Res. No. 2023-3",
#     "entityType": "Resolution",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "amended",
#         "relationshipTarget": {
#           "entityName": "Chapter 60",
#           "entityType": "Legal Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Res. No. 2007-2",
#     "entityType": "Resolution",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "adoptedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Exhibit A",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "title",
#         "propertyValue": "monthly billing calculation"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "CTSA Engineer",
#     "entityType": "Profession",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "53 P.S. \u00a7 10101 et seq.",
#     "entityType": "Legal Code",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "CONEWAGO CODE",
#     "entityType": "Legal Code",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "BIOCHEMICAL OXYGEN DEMAND (BOD)",
#     "entityType": "Measurement",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "EQUIVALENT DWELLING UNIT (EDU)",
#     "entityType": "Measurement",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "HIGH STRENGTH WASTE CUSTOMER",
#     "entityType": "Customer",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "LOADING",
#     "entityType": "Measurement",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "SURFACTANT",
#     "entityType": "Chemical",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "High strength waste customer",
#     "entityType": "Customer",
#     "properties": [
#       {
#         "propertyName": "Billing Rate",
#         "propertyValue": "Current per-EDU user rate for the greater of calculated organic capacity or hydraulic capacity"
#       },
#       {
#         "propertyName": "Testing Fee",
#         "propertyValue": "$175 per test after the first test of each month"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Bills",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Consulting Engineer",
#     "entityType": "Profession",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Employed By",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Property Owner",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Owns",
#         "relationshipTarget": {
#           "entityName": "Property",
#           "entityType": "RealEstate"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "York County Prison",
#     "entityType": "Location",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania's Sunshine Act",
#     "entityType": "Law",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 71",
#     "entityType": "DocumentSection",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "HIGH STRENGTH WASTE"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 82",
#     "entityType": "DocumentSection",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "INFILTRATION AND DETECTION"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 99",
#     "entityType": "DocumentSection",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "MEETING RECORDINGS"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Magisterial District Judge",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "Location",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania Municipal Records Act",
#     "entityType": "Law",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Municipal Records Manual - Retention and Disposition Schedule for Records of Pennsylvania Municipal Governments",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Approval Date",
#         "propertyValue": "December 16, 2018"
#       },
#       {
#         "propertyName": "Amendment Date",
#         "propertyValue": "March 28, 2019"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A, Landlord Responsibility Acknowledgement Form",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 132",
#     "entityType": "Chapter",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "QUALIFIED PERSONS AND INSTALLERS"
#       },
#       {
#         "propertyName": "AdoptionDate",
#         "propertyValue": "2-11-1993"
#       },
#       {
#         "propertyName": "AdoptionResolution",
#         "propertyValue": "Res. No. 1993-3"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "AdoptedBy",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 132-1",
#     "entityType": "Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Definitions"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "BelongsTo",
#         "relationshipTarget": {
#           "entityName": "Chapter 132",
#           "entityType": "Chapter"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "53 Pa.C.S.A \u00a7 1381 et seq.",
#     "entityType": "LegalCode",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 150, Sewer Rules and Regulations",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "ReferencedIn",
#         "relationshipTarget": {
#           "entityName": "\u00a7 150-30",
#           "entityType": "DocumentSection"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "\u00a7 150-30",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-2",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-3",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "GovernmentalBody",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Commonwealth of Pennsylvania",
#     "entityType": "GovernmentalBody",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Federal Occupational Safety and Health Administration",
#     "entityType": "GovernmentalBody",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania Department of Transportation",
#     "entityType": "GovernmentalBody",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania Department of Environmental Protection",
#     "entityType": "GovernmentalBody",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-4",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-5",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-6",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-7",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "York County Prison",
#     "entityType": "Facility",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-8",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-9",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-10",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 132-11",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 144-1",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "CTSA",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Department of Environmental Protection Municipal Wasteload Management Regulations",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 144-2",
#     "entityType": "DocumentSection",
#     "properties": [],
#     "relationships": []
#   }
# ]
# 10941
# [
#   {
#     "entityName": "Conewago Township Sewer Authority",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Location",
#         "propertyValue": "Conewago Township, Pennsylvania"
#       },
#       {
#         "propertyName": "Type",
#         "propertyValue": "Municipal Authority"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "CTSA",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Full Name",
#         "propertyValue": "Conewago Township Sewer Authority"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 150",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Sewer Rules and Regulations"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Article I",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Terminology"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Chapter 150",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Article II",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Use of Public Sewers Required"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Chapter 150",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 144-3",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Authority to exceed buffer threshold"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Unknown",
#           "entityType": "Chapter"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 150-1",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Definitions"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Article I",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 150-2",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Improved properties to be connected to accessible sewers"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Article II",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 150-3",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Sewage and certain industrial wastes to be discharged into sewers"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Article II",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 150-4",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Unlawful discharge or deposit of sewage and industrial wastes"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Article II",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 150-5",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Unlawful discharge into sewer"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Article II",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Section 150-6",
#     "entityType": "Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Certain receptacles not to be used on improved property accessible to sewer; abandonment of such receptacles"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Part Of",
#         "relationshipTarget": {
#           "entityName": "Article II",
#           "entityType": "Document Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "AASHTO No. 8 coarse aggregate stone dust",
#     "entityType": "Material",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "1B stone",
#     "entityType": "Material",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Authority",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Issues",
#         "relationshipTarget": {
#           "entityName": "Sewer Connection Permit",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Observes",
#         "relationshipTarget": {
#           "entityName": "Work of Connection",
#           "entityType": "Activity"
#         }
#       },
#       {
#         "relationshipType": "Inspects",
#         "relationshipTarget": {
#           "entityName": "Building Sewer",
#           "entityType": "Structure"
#         }
#       },
#       {
#         "relationshipType": "Imposes",
#         "relationshipTarget": {
#           "entityName": "Tapping Fee",
#           "entityType": "Fee"
#         }
#       },
#       {
#         "relationshipType": "Imposes",
#         "relationshipTarget": {
#           "entityName": "Connection Charge",
#           "entityType": "Fee"
#         }
#       },
#       {
#         "relationshipType": "Imposes",
#         "relationshipTarget": {
#           "entityName": "Reserve Capacity Charges",
#           "entityType": "Fee"
#         }
#       },
#       {
#         "relationshipType": "Imposes",
#         "relationshipTarget": {
#           "entityName": "Other Fees",
#           "entityType": "Fee"
#         }
#       },
#       {
#         "relationshipType": "Collects",
#         "relationshipTarget": {
#           "entityName": "Costs and Expenses",
#           "entityType": "Financial Transaction"
#         }
#       },
#       {
#         "relationshipType": "Determines",
#         "relationshipTarget": {
#           "entityName": "User Fee Rates",
#           "entityType": "Rate"
#         }
#       },
#       {
#         "relationshipType": "Gives Notice To",
#         "relationshipTarget": {
#           "entityName": "Owner",
#           "entityType": "Person"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Sewer Connection Permit",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Validity Period",
#         "propertyValue": "Nine Months"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Required By",
#         "relationshipTarget": {
#           "entityName": "Section 150-8",
#           "entityType": "Legal Section"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Owner",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Owns",
#         "relationshipTarget": {
#           "entityName": "Improved Property",
#           "entityType": "Property"
#         }
#       },
#       {
#         "relationshipType": "Pays",
#         "relationshipTarget": {
#           "entityName": "Costs and Expenses",
#           "entityType": "Financial Transaction"
#         }
#       },
#       {
#         "relationshipType": "Pays",
#         "relationshipTarget": {
#           "entityName": "User Fee",
#           "entityType": "Fee"
#         }
#       },
#       {
#         "relationshipType": "Applies For",
#         "relationshipTarget": {
#           "entityName": "Sewer Connection Permit",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Enters Into",
#         "relationshipTarget": {
#           "entityName": "Reserve Capacity Agreement",
#           "entityType": "Agreement"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Improved Property",
#     "entityType": "Property",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Connected To",
#         "relationshipTarget": {
#           "entityName": "Sewer",
#           "entityType": "Infrastructure"
#         }
#       },
#       {
#         "relationshipType": "Served By",
#         "relationshipTarget": {
#           "entityName": "Building Sewer",
#           "entityType": "Structure"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Building Sewer",
#     "entityType": "Structure",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Connects To",
#         "relationshipTarget": {
#           "entityName": "Sewer",
#           "entityType": "Infrastructure"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Sewer",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Reserve Capacity Agreement",
#     "entityType": "Agreement",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 150-8",
#     "entityType": "Legal Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 150-2",
#     "entityType": "Legal Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 150-17",
#     "entityType": "Legal Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Fernco",
#     "entityType": "Unknown",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Costs and Expenses",
#     "entityType": "Financial Transaction",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "User Fee",
#     "entityType": "Fee",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Tapping Fee",
#     "entityType": "Fee",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Connection Charge",
#     "entityType": "Fee",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Reserve Capacity Charges",
#     "entityType": "Fee",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Other Fees",
#     "entityType": "Fee",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "User Fee Rates",
#     "entityType": "Rate",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Work of Connection",
#     "entityType": "Activity",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Applicant",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": []
#   }
# ]
# 9742
# [
#   {
#     "entityName": "Authority",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Employs",
#         "relationshipTarget": {
#           "entityName": "Engineer",
#           "entityType": "Profession"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "ASTM 74 service class",
#     "entityType": "Standard",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "AASHTO No. 8 coarse aggregate",
#     "entityType": "Material",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "SDR 35 PVC pipe",
#     "entityType": "Material",
#     "properties": [
#       {
#         "propertyName": "joint_type",
#         "propertyValue": "rubber gasketed"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Schedule 40 PVC pipe",
#     "entityType": "Material",
#     "properties": [
#       {
#         "propertyName": "joint_type",
#         "propertyValue": "solvent welded"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Class 50 ductile iron pipe",
#     "entityType": "Material",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "cast-iron soil pipe",
#     "entityType": "Material",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "building sewer",
#     "entityType": "Infrastructure",
#     "properties": [
#       {
#         "propertyName": "minimum_inside_diameter",
#         "propertyValue": "four inches"
#       },
#       {
#         "propertyName": "minimum_grade",
#         "propertyValue": "1/4 inch per foot"
#       },
#       {
#         "propertyName": "minimum_cover",
#         "propertyValue": "2 1/2 feet"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "connected_to",
#         "relationshipTarget": {
#           "entityName": "sanitary sewer system",
#           "entityType": "Infrastructure"
#         }
#       },
#       {
#         "relationshipType": "inspected_by",
#         "relationshipTarget": {
#           "entityName": "Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "sanitary sewer system",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "manholes",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "service lateral",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "sewer main",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "trap",
#     "entityType": "Infrastructure",
#     "properties": [
#       {
#         "propertyName": "type",
#         "propertyValue": "single plug running trap"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "vent",
#     "entityType": "Infrastructure",
#     "properties": [
#       {
#         "propertyName": "minimum_height_above_ground",
#         "propertyValue": "12 inches"
#       },
#       {
#         "propertyName": "minimum_diameter",
#         "propertyValue": "four inches"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "cleanouts",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "auger",
#     "entityType": "Tool",
#     "properties": [
#       {
#         "propertyName": "length",
#         "propertyValue": "fifty-foot-long"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "warning tape",
#     "entityType": "Material",
#     "properties": [
#       {
#         "propertyName": "material",
#         "propertyValue": "magnetic polyethylene tape"
#       },
#       {
#         "propertyName": "width",
#         "propertyValue": "three inches"
#       },
#       {
#         "propertyName": "minimum_lettering",
#         "propertyValue": "one-inch-minimum"
#       },
#       {
#         "propertyName": "burial_depth_ground",
#         "propertyValue": "12 inches"
#       },
#       {
#         "propertyName": "burial_depth_pavement",
#         "propertyValue": "12 inches below the top of the subgrade"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "connection permit",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "improved property",
#     "entityType": "Property",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "owner",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Engineer",
#     "entityType": "Profession",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Township Plumbing Code",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "grinder stations",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "contractor",
#     "entityType": "Profession",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Interceptors",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "separators",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "York Concrete Products",
#     "entityType": "Company",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit \"A\"",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Content",
#         "propertyValue": "Oil Interceptor Detail"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit \"B\"",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Content",
#         "propertyValue": "Grease Interceptor Detail"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit \"C\"",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Content",
#         "propertyValue": "Control Manhole Detail"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 1993-4",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 2023-1",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township Sewer Authority",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Location",
#         "propertyValue": "Conewago Township, PA"
#       },
#       {
#         "propertyName": "Function",
#         "propertyValue": "Owns, maintains, and operates sewerage facilities"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Act 537 Sewerage Facilities Plan",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Purpose",
#         "propertyValue": "Designates the ultimate needs of an area to be served by sewerage facilities"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Governs",
#         "relationshipTarget": {
#           "entityName": "Sewerage facility extensions",
#           "entityType": "Infrastructure"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Army Corps of Engineers",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Regulation",
#         "propertyValue": "Section 404 of the Clean Water Act"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Clean Water Act",
#     "entityType": "Law",
#     "properties": [
#       {
#         "propertyName": "Section 404",
#         "propertyValue": "Regulates discharge of dredged or fill material into waters of the United States, including adjacent and isolated wetlands"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Regulates",
#         "relationshipTarget": {
#           "entityName": "Discharge of dredged or fill material",
#           "entityType": "Activity"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Pennsylvania Department of Environmental Protection (DEP)",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 105 (Dam Safety and Waterway Management)",
#     "entityType": "Law",
#     "properties": [
#       {
#         "propertyName": "Regulation",
#         "propertyValue": "Requires permit for construction in or alteration of Pennsylvania waterway, floodway, or body of water (including wetlands)"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Application to Construct Sewerage Facilities"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit B",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Checklist for Developers Plans"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit C",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Topic",
#         "propertyValue": "Specific application procedures for procurement of an industrial waste discharge permit"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Natural Resources Conservation Service",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Resource",
#         "propertyValue": "County Soil Survey"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "U.S. Fish and Wildlife Service",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Resource",
#         "propertyValue": "National Wetland Inventory Map(s)"
#       }
#     ],
#     "relationships": []
#   }
# ]
# 13907
# [
#   {
#     "entityName": "Conewago Township Sewer Authority",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "location",
#         "propertyValue": "PA"
#       },
#       {
#         "propertyName": "code",
#         "propertyValue": "\u00a7 150-38"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "approves",
#         "relationshipTarget": {
#           "entityName": "planning modules",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "receives application from",
#         "relationshipTarget": {
#           "entityName": "applicant",
#           "entityType": "Person"
#         }
#       },
#       {
#         "relationshipType": "employs",
#         "relationshipTarget": {
#           "entityName": "Authority's Engineer",
#           "entityType": "Person"
#         }
#       },
#       {
#         "relationshipType": "Issues",
#         "relationshipTarget": {
#           "entityName": "Letter of Approval",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Issues",
#         "relationshipTarget": {
#           "entityName": "Certificate of Satisfactory Construction",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Obtains",
#         "relationshipTarget": {
#           "entityName": "Highway Occupancy Permit",
#           "entityType": "Permit"
#         }
#       },
#       {
#         "relationshipType": "Approves",
#         "relationshipTarget": {
#           "entityName": "Application for Progress Release",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Establishes",
#         "relationshipTarget": {
#           "entityName": "Escrow",
#           "entityType": "Financial Account"
#         }
#       },
#       {
#         "relationshipType": "Approves",
#         "relationshipTarget": {
#           "entityName": "Schedule of Values",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Authorizes",
#         "relationshipTarget": {
#           "entityName": "Release of Financial Security",
#           "entityType": "Action"
#         }
#       },
#       {
#         "relationshipType": "Has",
#         "relationshipTarget": {
#           "entityName": "Inspector",
#           "entityType": "Person"
#         }
#       },
#       {
#         "relationshipType": "Has",
#         "relationshipTarget": {
#           "entityName": "Engineer",
#           "entityType": "Person"
#         }
#       },
#       {
#         "relationshipType": "Approves",
#         "relationshipTarget": {
#           "entityName": "Developer Specifications",
#           "entityType": "Document"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "DEP",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "approves",
#         "relationshipTarget": {
#           "entityName": "planning modules",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "requires",
#         "relationshipTarget": {
#           "entityName": "water quality management permit application",
#           "entityType": "Document"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Township",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "approves",
#         "relationshipTarget": {
#           "entityName": "planning modules",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "issues",
#         "relationshipTarget": {
#           "entityName": "postcard application",
#           "entityType": "Document"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "applicant",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "submits",
#         "relationshipTarget": {
#           "entityName": "application",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "submits",
#         "relationshipTarget": {
#           "entityName": "planning module component",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "submits",
#         "relationshipTarget": {
#           "entityName": "preliminary plan",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "submits",
#         "relationshipTarget": {
#           "entityName": "final plans",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "submits",
#         "relationshipTarget": {
#           "entityName": "water quality management permit application",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "executes",
#         "relationshipTarget": {
#           "entityName": "standard agreements",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "submits",
#         "relationshipTarget": {
#           "entityName": "final application",
#           "entityType": "Document"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Authority's Engineer",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "reviews",
#         "relationshipTarget": {
#           "entityName": "preliminary application",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "provides",
#         "relationshipTarget": {
#           "entityName": "letter report",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Prepares",
#         "relationshipTarget": {
#           "entityName": "Record Drawings",
#           "entityType": "Document"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Pennsylvania Department of Environmental Protection",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "requires",
#         "relationshipTarget": {
#           "entityName": "final plans",
#           "entityType": "Document"
# ...
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Dover treatment plant",
#     "entityType": "Facility",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "Governmental Body",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Westwood Mobile Home Park",
#     "entityType": "Residential Park",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Westwood Drive",
#     "entityType": "Road",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Act 203",
#     "entityType": "Legislation",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 2015-1",
#     "entityType": "Resolution",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "2-28-2015"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 2000-1",
#     "entityType": "Resolution",
#     "properties": [
#       {
#         "propertyName": "Amendment Date",
#         "propertyValue": "4-6-2000"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 2022-1",
#     "entityType": "Resolution",
#     "properties": [
#       {
#         "propertyName": "Amendment Date",
#         "propertyValue": "10-25-2022"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Equivalent Dwelling Unit (EDU)",
#     "entityType": "Unit of Measurement",
#     "properties": [
#       {
#         "propertyName": "Definition",
#         "propertyValue": "300 gallons per day per dwelling unit"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 150, Sewer Rules and Regulations",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "53 Pa.C.S.A. \u00a7 5601 et seq.",
#     "entityType": "Legal Code",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Authority's Engineer",
#     "entityType": "Profession",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Employed By",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Pennsylvania Department of Environmental Protection",
#     "entityType": "Governmental Agency",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Regulates",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Pennsylvania Infrastructure Investment Authority",
#     "entityType": "Governmental Agency",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Dover Township Wastewater Treatment Plant",
#     "entityType": "Facility",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "York County Prison",
#     "entityType": "Facility",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Unknown",
#     "entityType": "Magisterial District Judge",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter 175",
#     "entityType": "Legal Document",
#     "properties": [
#       {
#         "propertyName": "Sections",
#         "propertyValue": "175-12, 175-13"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Resolution 1992-2",
#     "entityType": "Legal Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Resolution 2005-1",
#     "entityType": "Legal Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Article VII",
#     "entityType": "Legal Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Declaration of Purpose"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Article VIII",
#     "entityType": "Legal Document Section",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Imposition of Tapping Fee on New Connections to Sewer System and Other Fees"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "York Water Company",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "Geographic Location",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania",
#     "entityType": "Geographic Location",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 175-14",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 175-15",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 175-16",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 188-1",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 188-2",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 188-3",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Section 188-4",
#     "entityType": "Legal Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania Infrastructure Investment Authority",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "1990 Promissory Note",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "7-24-1990"
#       },
#       {
#         "propertyName": "Resolution Number",
#         "propertyValue": "1990-1"
#       },
#       {
#         "propertyName": "Funding Amount",
#         "propertyValue": "$7,000,000"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "2002 Promissory Note",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "7-23-2002"
#       },
#       {
#         "propertyName": "Resolution Number",
#         "propertyValue": "2002-2"
#       },
#       {
#         "propertyName": "Project Name",
#         "propertyValue": "Guaranteed Sewer Project Note - Series of 2000"
#       },
#       {
#         "propertyName": "Funding Amount",
#         "propertyValue": "$3,876,000"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "PENNVEST",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Acquisition of Land for Sewer Collection System",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "5-7-1991"
#       },
#       {
#         "propertyName": "Resolution Number",
#         "propertyValue": "1991-1"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Unknown",
#     "entityType": "Law",
#     "properties": [],
#     "relationships": []
#   }
# ]
# 8602
# [
#   {
#     "entityName": "Conewago Township Sewer Authority",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Resolution Number",
#         "propertyValue": "2004-1"
#       },
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "8-24-2004"
#       },
#       {
#         "propertyName": "Resolution Number",
#         "propertyValue": "2016-1"
#       },
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "9-27-2016"
#       },
#       {
#         "propertyName": "Resolution",
#         "propertyValue": "No. 2020-1"
#       },
#       {
#         "propertyName": "Resolution",
#         "propertyValue": "No. 2020-2"
#       },
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "7-29-2020"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Adopted",
#         "relationshipTarget": {
#           "entityName": "Resolution No. 1991-2",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Adopted",
#         "relationshipTarget": {
#           "entityName": "Resolution No. 1991-3",
#           "entityType": "Document"
#         }
#       },
#       {
#         "relationshipType": "Owns",
#         "relationshipTarget": {
#           "entityName": "Sewage treatment and sewage collection system",
#           "entityType": "System"
#         }
#       },
#       {
#         "relationshipType": "Employs",
#         "relationshipTarget": {
#           "entityName": "Stephen P. Linebaugh",
#           "entityType": "Person"
#         }
#       },
#       {
#         "relationshipType": "Adopted",
#         "relationshipTarget": {
#           "entityName": "Reimbursement Agreement",
#           "entityType": "Agreement"
#         }
#       },
#       {
#         "relationshipType": "Party to",
#         "relationshipTarget": {
#           "entityName": "Sewer Extension Reimbursement Agreement",
#           "entityType": "Agreement"
#         }
#       },
#       {
#         "relationshipType": "Adopted",
#         "relationshipTarget": {
#           "entityName": "Resolution",
#           "entityType": "Document"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Resolution No. 1991-2",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "5-7-1991"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Resolution No. 1991-3",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "8-20-1991"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Stephen P. Linebaugh",
#     "entityType": "Person",
#     "properties": [
#       {
#         "propertyName": "Title",
#         "propertyValue": "Counsel to the Conewago Township Sewer Authority"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Location",
#         "propertyValue": "offices of the Conewago Township Sewer Authority"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A21",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A.22",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "Location",
#     "properties": [
#       {
#         "propertyName": "County",
#         "propertyValue": "York County, Pennsylvania"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Sewage treatment and sewage collection system",
#     "entityType": "System",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pressure Sewer",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Grinder Pump",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Sewage treatment plant",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pumping stations",
#     "entityType": "Infrastructure",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "F-T, LLLP",
#     "entityType": "Organization",
#     "properties": [
#       {
#         "propertyName": "Type",
#         "propertyValue": "Maryland Limited Liability Partnership"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Party to",
#         "relationshipTarget": {
#           "entityName": "Sewer Extension Reimbursement Agreement",
#           "entityType": "Agreement"
#         }
#       },
#       {
#         "relationshipType": "Developer of",
#         "relationshipTarget": {
#           "entityName": "Bennett Run Project",
#           "entityType": "Project"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Sewer Extension Reimbursement Agreement",
#     "entityType": "Agreement",
#     "properties": [
#       {
#         "propertyName": "Date",
#         "propertyValue": "May 25, 2004"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Bennett Run Project",
#     "entityType": "Project",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit A23",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Content",
#         "propertyValue": "Sewer Extension Reimbursement Agreement"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "Conewago Township",
#     "entityType": "GeographicLocation",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennsylvania Department of Transportation",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Undertaking",
#         "relationshipTarget": {
#           "entityName": "Highway Construction Project",
#           "entityType": "Project"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "State Route 0921",
#     "entityType": "Road",
#     "properties": [
#       {
#         "propertyName": "Location",
#         "propertyValue": "York County"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "York County",
#     "entityType": "GeographicLocation",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Resolution",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Utility Relocation and Reimbursement Agreement",
#     "entityType": "Contract",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "CTSA",
#     "entityType": "Organization",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Unknown",
#     "entityType": "Person",
#     "properties": [],
#     "relationships": [
#       {
#         "relationshipType": "Authorized to Sign",
#         "relationshipTarget": {
#           "entityName": "Utility Relocation and Reimbursement Agreement",
#           "entityType": "Contract"
#         }
#       },
#       {
#         "relationshipType": "Authorized to Attest",
#         "relationshipTarget": {
#           "entityName": "Utility Relocation and Reimbursement Agreement",
#           "entityType": "Contract"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Municipal Records Manual",
#     "entityType": "Document",
#     "properties": [
#       {
#         "propertyName": "Approval Date",
#         "propertyValue": "December 16, 2008"
#       }
#     ],
#     "relationships": [
#       {
#         "relationshipType": "Approved by",
#         "relationshipTarget": {
#           "entityName": "Conewago Township Sewer Authority",
#           "entityType": "Organization"
#         }
#       }
#     ]
#   },
#   {
#     "entityName": "Act 428 of 1968",
#     "entityType": "Legislation",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Exhibit24",
#     "entityType": "Document",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Chapter DL",
#     "entityType": "Document Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Res. No. 2020-2",
#     "entityType": "Legislation",
#     "properties": [
#       {
#         "propertyName": "Adoption Date",
#         "propertyValue": "July 28, 2020"
#       }
#     ],
#     "relationships": []
#   },
#   {
#     "entityName": "\u00a7 DL-1",
#     "entityType": "Legislation Section",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "PLGIT",
#     "entityType": "Unknown",
#     "properties": [],
#     "relationships": []
#   },
#   {
#     "entityName": "Pennvest",
#     "entityType": "Unknown",
#     "properties": [],
#     "relationships": []
#   }
# ]
# Done
